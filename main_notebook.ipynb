# %% [markdown]
# # Use this notbook for your 3 choices of APIs

# %%
import requests
import json
import pandas as pd
from bs4 import BeautifulSoup
from pandas.io.json import json_normalize

# %% [markdown]
# # 1st API

# %%
response_exchange_rates = requests.get('https://api.coingecko.com/api/v3/exchange_rates')
response_exchange_rates
# Out:
# <Response [200]>

# %%
# Dataframe has everything nested in 1 column

data_exchange_rates = pd.DataFrame(response_exchange_rates.json())
data_exchange_rates.head()
# Out:
#                                                  rates
# aed  {'name': 'United Arab Emirates Dirham', 'unit'...
# ars  {'name': 'Argentine Peso', 'unit': '$', 'value...
# aud  {'name': 'Australian Dollar', 'unit': 'A$', 'v...
# bch  {'name': 'Bitcoin Cash', 'unit': 'BCH', 'value...
# bdt  {'name': 'Bangladeshi Taka', 'unit': '৳', 'val...

# %%
data_exchange_rates.shape
# Out:
# (61, 1)

# %%
# This did not work so I opted to use the function

flattened_data = json_normalize(data_exchange_rates['rates'])

flattened_data
# Out:
# C:\Users\13306\AppData\Local\Temp\ipykernel_18712\1285626517.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattened_data = json_normalize(data_exchange_rates['rates'])
#                            name unit        value    type
# 0   United Arab Emirates Dirham   DH    70284.009    fiat
# 1                Argentine Peso    $  2886368.683    fiat
# 2             Australian Dollar   A$    30437.422    fiat
# 3                  Bitcoin Cash  BCH      171.953  crypto
# 4              Bangladeshi Taka    ৳  1944092.822    fiat
# ..                          ...  ...          ...     ...
# 56   IMF Special Drawing Rights  XDR    13620.021    fiat
# 57                       Lumens  XLM   160956.773  crypto
# 58                          XRP  XRP    38975.648  crypto
# 59                Yearn.finance  YFI        2.424  crypto
# 60           South African Rand    R   346965.370    fiat
#
# [61 rows x 4 columns]

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
dict(data_exchange_rates['rates'])
pd.DataFrame(dict(data_exchange_rates['rates']))
pd.DataFrame(dict(data_exchange_rates['rates'])).transpose()
# Out:
#                             name unit        value    type
# aed  United Arab Emirates Dirham   DH    70284.009    fiat
# ars               Argentine Peso    $  2886368.683    fiat
# aud            Australian Dollar   A$    30437.422    fiat
# bch                 Bitcoin Cash  BCH      171.953  crypto
# bdt             Bangladeshi Taka    ৳  1944092.822    fiat
# ..                           ...  ...          ...     ...
# xdr   IMF Special Drawing Rights  XDR    13620.021    fiat
# xlm                       Lumens  XLM   160956.773  crypto
# xrp                          XRP  XRP    38975.648  crypto
# yfi                Yearn.finance  YFI        2.424  crypto
# zar           South African Rand    R    346965.37    fiat
#
# [61 rows x 4 columns]

# %%
flatten(data_exchange_rates,['rates'])
# Out:
#                       rates_name rates_unit  rates_value rates_type
# aed  United Arab Emirates Dirham         DH    70284.009       fiat
# ars               Argentine Peso          $  2886368.683       fiat
# aud            Australian Dollar         A$    30437.422       fiat
# bch                 Bitcoin Cash        BCH      171.953     crypto
# bdt             Bangladeshi Taka          ৳  1944092.822       fiat
# ..                           ...        ...          ...        ...
# xdr   IMF Special Drawing Rights        XDR    13620.021       fiat
# xlm                       Lumens        XLM   160956.773     crypto
# xrp                          XRP        XRP    38975.648     crypto
# yfi                Yearn.finance        YFI        2.424     crypto
# zar           South African Rand          R    346965.37       fiat
#
# [61 rows x 4 columns]

# %% [markdown]
# # 2nd API

# %%
response_population = requests.get('https://datausa.io/api/data?drilldowns=Nation&measures=Population')
a = response_population.json()

# %%
a.keys()
# Out:
# dict_keys(['data', 'source'])

# %%
#this data has imbeded dictionaries

# %%
a['data']
# Out:
# [{'ID Nation': '01000US',
#   'Nation': 'United States',
#   'ID Year': 2020,
#   'Year': '2020',
#   'Population': 326569308,
#   'Slug Nation': 'united-states'},
#  {'ID Nation': '01000US',
#   'Nation': 'United States',
#   'ID Year': 2019,
#   'Year': '2019',
#   'Population': 324697795,
#   'Slug Nation': 'united-states'},
#  {'ID Nation': '01000US',
#   'Nation': 'United States',
#   'ID Year': 2018,
#   'Year': '2018',
#   'Population': 322903030,
#   'Slug Nation': 'united-states'},
#  {'ID Nation': '01000US',
#   'Nation': 'United States',
#   'ID Year': 2017,
#   'Year': '2017',
#   'Population': 321004407,
#   'Slug Nation': 'united-states'},
#  {'ID Nation': '01000US',
#   'Nation': 'United States',
#   'ID Year': 2016,
#   'Year': '2016',
#   'Population': 318558162,
#   'Slug Nation': 'united-states'},
#  {'ID Nation': '01000US',
#   'Nation': 'United States',
#   'ID Year': 2015,
#   'Year': '2015',
#   'Population': 316515021,
#   'Slug Nation': 'united-states'},
#  {'ID Nation': '01000US',
#   'Nation': 'United States',
#   'ID Year': 2014,
#   'Year': '2014',
#   'Population': 314107084,
#   'Slug Nation': 'united-states'},
#  {'ID Nation': '01000US',
#   'Nation': 'United States',
#   'ID Year': 2013,
#   'Year': '2013',
#   'Population': 311536594,
#   'Slug Nation': 'united-states'}]

# %%
data_population = pd.DataFrame(a['data'])
data_population.head()
# Out:
#   ID Nation         Nation  ID Year  Year  Population    Slug Nation
# 0   01000US  United States     2020  2020   326569308  united-states
# 1   01000US  United States     2019  2019   324697795  united-states
# 2   01000US  United States     2018  2018   322903030  united-states
# 3   01000US  United States     2017  2017   321004407  united-states
# 4   01000US  United States     2016  2016   318558162  united-states

# %%
a['source']
# Out:
# [{'measures': ['Population'],
#   'annotations': {'source_name': 'Census Bureau',
#    'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#    'dataset_name': 'ACS 5-year Estimate',
#    'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#    'table_id': 'B01003',
#    'topic': 'Diversity',
#    'subtopic': 'Demographics'},
#   'name': 'acs_yg_total_population_5',
#   'substitutions': []}]

# %%
data_population2 = pd.DataFrame(a['source'])
data_population2.head()
# Out:
#        measures                                        annotations  \
# 0  [Population]  {'source_name': 'Census Bureau', 'source_descr...
#
#                         name substitutions
# 0  acs_yg_total_population_5            []

# %%
test = pd.DataFrame({"header":response_population})
test
# Out:
#                                                header
# 0   b'{"data":[{"ID Nation":"01000US","Nation":"Un...
# 1   b'ed-states"},{"ID Nation":"01000US","Nation":...
# 2   b'nited-states"},{"ID Nation":"01000US","Natio...
# 3   b':"united-states"},{"ID Nation":"01000US","Na...
# 4   b'on":"united-states"},{"ID Nation":"01000US",...
# 5   b'ation":"united-states"},{"ID Nation":"01000U...
# 6   b'g Nation":"united-states"},{"ID Nation":"010...
# 7   b'Slug Nation":"united-states"},{"ID Nation":"...
# 8   b'4,"Slug Nation":"united-states"}],"source":[...
# 9   b'ription":"The American Community Survey (ACS...
# 10  b',"dataset_name":"ACS 5-year Estimate","datas...
# 11  b'Diversity","subtopic":"Demographics"},"name"...

# %% [markdown]
# # 3rd API

# %%
house_stocks = requests.get('https://house-stock-watcher-data.s3-us-west-2.amazonaws.com/data/all_transactions.json')
house_stocks
# Out:
# <Response [200]>

# %%
house_stocks.json()
# Out:
# [{'disclosure_year': 2021,
#   'disclosure_date': '10/04/2021',
#   'transaction_date': '2021-09-27',
#   'owner': 'joint',
#   'ticker': 'BP',
#   'asset_description': 'BP plc',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Virginia Foxx',
#   'district': 'NC05',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20019557.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '10/04/2021',
#   'transaction_date': '2021-09-13',
#   'owner': 'joint',
#   'ticker': 'XOM',
#   'asset_description': 'Exxon Mobil Corporation',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Virginia Foxx',
#   'district': 'NC05',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20019557.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '10/04/2021',
#   'transaction_date': '2021-09-10',
#   'owner': 'joint',
#   'ticker': 'ILPT',
#   'asset_description': 'Industrial Logistics Properties Trust - Common Shares of Beneficial Interest',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Virginia Foxx',
#   'district': 'NC05',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20019557.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '10/04/2021',
#   'transaction_date': '2021-09-28',
#   'owner': 'joint',
#   'ticker': 'PM',
#   'asset_description': 'Phillip Morris International Inc',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Virginia Foxx',
#   'district': 'NC05',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20019557.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '10/04/2021',
#   'transaction_date': '2021-09-17',
#   'owner': 'self',
#   'ticker': 'BLK',
#   'asset_description': 'BlackRock Inc',
#   'type': 'sale_partial',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Alan S. Lowenthal',
#   'district': 'CA47',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20019570.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '12/01/2021',
#   'transaction_date': '2021-12-01',
#   'owner': 'joint',
#   'ticker': 'AXP',
#   'asset_description': 'American Express Company',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Aston Donald McEachin',
#   'district': 'VA04',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20019930.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '12/01/2021',
#   'transaction_date': '2021-11-30',
#   'owner': None,
#   'ticker': 'KPLTW',
#   'asset_description': 'Katapult Holdings Inc - Warrant',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Austin Scott',
#   'district': 'GA08',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20019915.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '12/01/2021',
#   'transaction_date': '2021-11-18',
#   'owner': None,
#   'ticker': 'AMD',
#   'asset_description': 'Advanced Micro Devices Inc',
#   'type': 'sale_full',
#   'amount': '$50,001 - $100,000',
#   'representative': 'Hon. Thomas Suozzi',
#   'district': 'NY03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20019917.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '12/01/2021',
#   'transaction_date': '2021-11-18',
#   'owner': None,
#   'ticker': 'AAPL',
#   'asset_description': 'Apple Inc',
#   'type': 'sale_full',
#   'amount': '$50,001 - $100,000',
#   'representative': 'Hon. Thomas Suozzi',
#   'district': 'NY03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20019917.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '12/01/2021',
#   'transaction_date': '2021-11-24',
#   'owner': None,
#   'ticker': 'MSFT',
#   'asset_description': 'Microsoft Corporation',
#   'type': 'purchase',
#   'amount': '$50,001 - $100,000',
#   'representative': 'Hon. Thomas Suozzi',
#   'district': 'NY03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20019917.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '12/01/2021',
#   'transaction_date': '2021-11-24',
#   'owner': None,
#   'ticker': 'MS',
#   'asset_description': 'Morgan Stanley',
#   'type': 'purchase',
#   'amount': '$100,001 - $250,000',
#   'representative': 'Hon. Thomas Suozzi',
#   'district': 'NY03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20019917.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '12/01/2021',
#   'transaction_date': '2021-11-16',
#   'owner': None,
#   'ticker': 'NEE',
#   'asset_description': 'NextEra Energy Inc',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Thomas Suozzi',
#   'district': 'NY03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20019917.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '12/01/2021',
#   'transaction_date': '2021-11-16',
#   'owner': None,
#   'ticker': 'SLVM',
#   'asset_description': 'Sylvamo Coproration',
#   'type': 'sale_full',
#   'amount': '$1,001 -',
#   'representative': 'Hon. Thomas Suozzi',
#   'district': 'NY03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20019917.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '12/01/2021',
#   'transaction_date': '2021-11-18',
#   'owner': None,
#   'ticker': 'CG',
#   'asset_description': 'The Carlyle Group Inc',
#   'type': 'sale_full',
#   'amount': '$50,001 - $100,000',
#   'representative': 'Hon. Thomas Suozzi',
#   'district': 'NY03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20019917.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '11/02/2021',
#   'transaction_date': '2021-10-13',
#   'owner': 'joint',
#   'ticker': 'MO',
#   'asset_description': 'Altria Group Inc',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Virginia Foxx',
#   'district': 'NC05',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20019717.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '11/02/2021',
#   'transaction_date': '2021-10-07',
#   'owner': 'joint',
#   'ticker': 'DUKH',
#   'asset_description': 'Duke Energy Corporation 5.125% Junior Subordinated Debentures due 2073',
#   'type': 'sale_full',
#   'amount': '$50,001 - $100,000',
#   'representative': 'Hon. Virginia Foxx',
#   'district': 'NC05',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20019717.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '11/02/2021',
#   'transaction_date': '2021-10-08',
#   'owner': 'joint',
#   'ticker': 'GSK',
#   'asset_description': 'GlaxoSmithKline PLC',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Virginia Foxx',
#   'district': 'NC05',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20019717.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '11/02/2021',
#   'transaction_date': '2021-10-07',
#   'owner': 'joint',
#   'ticker': 'OLP',
#   'asset_description': 'One Liberty Properties Inc',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Virginia Foxx',
#   'district': 'NC05',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20019717.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '11/02/2021',
#   'transaction_date': '2021-10-04',
#   'owner': 'joint',
#   'ticker': 'PPL',
#   'asset_description': 'PPL Corporation',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Virginia Foxx',
#   'district': 'NC05',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20019717.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '11/02/2021',
#   'transaction_date': '2021-10-25',
#   'owner': 'joint',
#   'ticker': 'SCU',
#   'asset_description': 'Sculptor Capital Management Inc Class A',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Virginia Foxx',
#   'district': 'NC05',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20019717.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '11/02/2021',
#   'transaction_date': '2021-10-26',
#   'owner': 'joint',
#   'ticker': 'SCU',
#   'asset_description': 'Sculptor Capital Management Inc Class A',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Virginia Foxx',
#   'district': 'NC05',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20019717.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '11/02/2021',
#   'transaction_date': '2021-10-08',
#   'owner': 'joint',
#   'ticker': 'VIASP',
#   'asset_description': 'Via Renewables Inc - 8.75% Series A Fixed-to-Floating Rate Cumulative Redeemable Perpetual Preferred Stock',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Virginia Foxx',
#   'district': 'NC05',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20019717.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'ACAD',
#   'asset_description': 'ACADIA Pharmaceuticals Inc',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-21',
#   'owner': None,
#   'ticker': 'AGNC',
#   'asset_description': 'AGNC Investment Corp',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'ALLK',
#   'asset_description': 'Allakos Inc',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'PLAN',
#   'asset_description': 'Anaplan Inc',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'ASB',
#   'asset_description': 'Associated Banc-Corp',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'BCEL',
#   'asset_description': 'Atreca Inc - Class A',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'AXSM',
#   'asset_description': 'Axsome Therapeutics Inc',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'SQ',
#   'asset_description': 'Square Inc Class A Common Stock',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-21',
#   'owner': None,
#   'ticker': 'BRMK',
#   'asset_description': 'Broadmark Realty Capital Inc',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'CPE',
#   'asset_description': 'Callon Petroleum Company',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-21',
#   'owner': None,
#   'ticker': 'SAVA',
#   'asset_description': 'Cassava Sciences Inc',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'CDEV',
#   'asset_description': 'Centennial Resource Development Inc - Class A',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-21',
#   'owner': None,
#   'ticker': 'CIVI',
#   'asset_description': 'Civitas Resources inc',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-21',
#   'owner': None,
#   'ticker': 'CTRA',
#   'asset_description': 'Coterra Energy Inc',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'UUUU',
#   'asset_description': 'Energy Fuels Inc Ordinary Shares',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'EXPE',
#   'asset_description': 'Expedia Group Inc',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-21',
#   'owner': None,
#   'ticker': 'FNB',
#   'asset_description': 'FNB Corporation',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-21',
#   'owner': None,
#   'ticker': 'FHN',
#   'asset_description': 'First Horizon Corporation',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-21',
#   'owner': None,
#   'ticker': 'GNKOQ',
#   'asset_description': 'Geneco Shipping & Trading Limited',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'GNK',
#   'asset_description': 'Geneco Shipping & Trading Limited Ordinary Shares',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'GEVO',
#   'asset_description': 'Geco Inc',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'HD',
#   'asset_description': 'Home Depot inc',
#   'type': 'sale_full',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-21',
#   'owner': None,
#   'ticker': 'IIPR',
#   'asset_description': 'Innovative Industrial Properties Inc',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-21',
#   'owner': None,
#   'ticker': 'KRG',
#   'asset_description': 'Kite Realty Group Trust',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'KOS',
#   'asset_description': 'Kosmos Energy Ltd Common Shares',
#   'type': 'sale_full',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'MAC',
#   'asset_description': 'Macerich Company',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'NBR',
#   'asset_description': 'Nabors Industries Ltd',
#   'type': 'sale_partial',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-30',
#   'owner': None,
#   'ticker': '--',
#   'asset_description': 'New York St 5%',
#   'type': 'purchase',
#   'amount': '$250,001 - $500,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'NEX',
#   'asset_description': 'NexTier Oilfield Solutions Inc',
#   'type': 'sale_full',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'NAT',
#   'asset_description': 'Nordic American Tankers Limited',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-21',
#   'owner': None,
#   'ticker': 'NWBI',
#   'asset_description': 'Northwest Bancshares Inc',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-21',
#   'owner': None,
#   'ticker': 'OCFC',
#   'asset_description': 'OceanFirst Financial Corp',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'OCGN',
#   'asset_description': 'Ocugen Inc',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'PTEN',
#   'asset_description': 'Patterson-UTI Energy Inc',
#   'type': 'sale_full',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-21',
#   'owner': None,
#   'ticker': 'DOC',
#   'asset_description': 'Physicians Realty Trust Common Shares of Beneficial Interest',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'RC',
#   'asset_description': 'Ready Capital Corporation',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'RC',
#   'asset_description': 'Ready Capital Corporation',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'RWT',
#   'asset_description': 'Redwood Trust Inc',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-21',
#   'owner': None,
#   'ticker': 'SBRA',
#   'asset_description': 'Sabra Health Care REIT, INC',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-21',
#   'owner': None,
#   'ticker': 'STNG',
#   'asset_description': 'Scorpio Tankers Inc Common Shares',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'TELL',
#   'asset_description': 'Tellurian Inc',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-21',
#   'owner': None,
#   'ticker': 'RTL',
#   'asset_description': 'The Necessity Retail REIT - Class A',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-21',
#   'owner': None,
#   'ticker': 'UBSI',
#   'asset_description': 'United Bankshares Inc',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'UEC',
#   'asset_description': 'Uranium Energy Corp',
#   'type': 'sale_full',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-21',
#   'owner': None,
#   'ticker': 'VTRSV',
#   'asset_description': 'Viatris Inc - Common Stock When Issued',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2022,
#   'disclosure_date': '07/28/2022',
#   'transaction_date': '2022-06-16',
#   'owner': None,
#   'ticker': 'VTRSV',
#   'asset_description': 'Viatris Inc - Common Stock When Issued',
#   'type': 'purchase',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Christopher L. Jacobs',
#   'district': 'NY27',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2022/20021398.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-02-24',
#   'owner': 'joint',
#   'ticker': 'BHC',
#   'asset_description': 'Bausch Health Companies Inc.',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-03-06',
#   'owner': 'joint',
#   'ticker': 'BAH',
#   'asset_description': 'Booz Allen Hamilton Holding Corporation',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-03-23',
#   'owner': 'joint',
#   'ticker': 'BYD',
#   'asset_description': 'Boyd Gaming Corporation',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-02-04',
#   'owner': 'joint',
#   'ticker': 'CTLT',
#   'asset_description': 'Catalent, Inc.',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-03-18',
#   'owner': 'joint',
#   'ticker': 'CBRE',
#   'asset_description': 'CBRE Group Inc Common Stock Class A',
#   'type': 'sale_partial',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-03-24',
#   'owner': 'joint',
#   'ticker': 'CNC',
#   'asset_description': 'Centene Corporation',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-03-31',
#   'owner': 'joint',
#   'ticker': 'DG',
#   'asset_description': 'Dollar General Corporation',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-02-26',
#   'owner': 'joint',
#   'ticker': 'DPZ',
#   'asset_description': "Domino's Pizza Inc",
#   'type': 'sale_partial',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-02-05',
#   'owner': 'joint',
#   'ticker': 'DNKN',
#   'asset_description': "Dunkin' Brands Group, Inc.",
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-02-24',
#   'owner': 'joint',
#   'ticker': 'ENV',
#   'asset_description': 'Envestnet, Inc',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-02-21',
#   'owner': 'joint',
#   'ticker': 'ENV',
#   'asset_description': 'Envestnet, Inc',
#   'type': 'sale_partial',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-03-06',
#   'owner': 'joint',
#   'ticker': 'AQUA',
#   'asset_description': 'Evoqua Water Technologies Corp.',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-03-17',
#   'owner': 'joint',
#   'ticker': 'LKQ',
#   'asset_description': 'LKQ Corporation',
#   'type': 'sale_partial',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-02-24',
#   'owner': 'joint',
#   'ticker': 'MAS',
#   'asset_description': 'Masco Corporation',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-02-05',
#   'owner': 'joint',
#   'ticker': 'NXST',
#   'asset_description': 'Nexstar Media Group, Inc. - Class A',
#   'type': 'sale_partial',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-02-24',
#   'owner': 'joint',
#   'ticker': 'OKE',
#   'asset_description': 'ONEOK, Inc.',
#   'type': 'sale_partial',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-03-09',
#   'owner': 'joint',
#   'ticker': 'OKE',
#   'asset_description': 'ONEOK, Inc.',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-02-24',
#   'owner': 'joint',
#   'ticker': 'PANW',
#   'asset_description': 'Palo alto Networks, Inc.',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-03-06',
#   'owner': 'joint',
#   'ticker': 'RP',
#   'asset_description': 'RealPage, Inc.',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-03-16',
#   'owner': 'joint',
#   'ticker': 'QSR',
#   'asset_description': 'Restaurant Brands International Inc. Common Shares',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-02-05',
#   'owner': 'joint',
#   'ticker': 'QSR',
#   'asset_description': 'Restaurant Brands International Inc. Common Shares',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-03-24',
#   'owner': 'joint',
#   'ticker': 'SCI',
#   'asset_description': 'Service Corporation International',
#   'type': 'sale_partial',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-02-25',
#   'owner': 'joint',
#   'ticker': 'COO',
#   'asset_description': 'The Cooper Companies, Inc.',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-02-24',
#   'owner': 'joint',
#   'ticker': 'UNVR',
#   'asset_description': 'Univar Solutions Inc.',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-03-17',
#   'owner': 'joint',
#   'ticker': 'USFD',
#   'asset_description': 'US Foods Holding Corp.',
#   'type': 'sale_partial',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-02-25',
#   'owner': 'joint',
#   'ticker': 'MTN',
#   'asset_description': 'Vail Resorts, Inc.',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-02-26',
#   'owner': 'joint',
#   'ticker': 'VLO',
#   'asset_description': 'Valero Energy Corporation',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-02-18',
#   'owner': 'joint',
#   'ticker': 'WAB',
#   'asset_description': 'Westinghouse air Brake Technologies Corporation',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-03-18',
#   'owner': 'joint',
#   'ticker': 'WH',
#   'asset_description': 'Wyndham Hotels & Resorts, Inc.',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-03-17',
#   'owner': 'joint',
#   'ticker': 'WH',
#   'asset_description': 'Wyndham Hotels & Resorts, Inc.',
#   'type': 'sale_partial',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-02-05',
#   'owner': 'joint',
#   'ticker': 'XPO',
#   'asset_description': 'XPO Logistics, Inc.',
#   'type': 'sale_partial',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Susie Lee',
#   'district': 'NV03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016193.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-03-16',
#   'owner': 'self',
#   'ticker': 'BRK.B',
#   'asset_description': 'Berkshire Hathaway Inc. New',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Alan S. Lowenthal',
#   'district': 'CA47',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016500.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-03-13',
#   'owner': 'self',
#   'ticker': 'BSX',
#   'asset_description': 'Boston Scientific Corporation',
#   'type': 'sale_partial',
#   'amount': '$1,001 -',
#   'representative': 'Hon. Alan S. Lowenthal',
#   'district': 'CA47',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016501.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2020,
#   'disclosure_date': '04/28/2020',
#   'transaction_date': '2020-03-13',
#   'owner': 'self',
#   'ticker': 'SPCE',
#   'asset_description': 'Virgin Galactic Holdings, Inc.',
#   'type': 'sale_partial',
#   'amount': '$1,001 -',
#   'representative': 'Hon. Alan S. Lowenthal',
#   'district': 'CA47',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20016501.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '09/22/2020',
#   'transaction_date': '2020-08-17',
#   'owner': None,
#   'ticker': '--',
#   'asset_description': 'Metallic Minerals Corp.',
#   'type': 'sale_partial',
#   'amount': '$100,001 - $250,000',
#   'representative': 'Mr. TJ John (Tj) Cox',
#   'district': 'CA21',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20017403.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/23/2021',
#   'transaction_date': '2021-01-27',
#   'owner': 'self',
#   'ticker': '--',
#   'asset_description': 'Zimmer Biomet Holdings',
#   'type': 'sale_partial',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Alan S. Lowenthal',
#   'district': 'CA47',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018447.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/23/2021',
#   'transaction_date': '2021-02-08',
#   'owner': None,
#   'ticker': '--',
#   'asset_description': 'Zimmer Biomet Holdings',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Alan S. Lowenthal',
#   'district': 'CA47',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018447.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/23/2021',
#   'transaction_date': '2021-02-08',
#   'owner': 'self',
#   'ticker': '--',
#   'asset_description': 'Zimmer Biomet Holdings',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Alan S. Lowenthal',
#   'district': 'CA47',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018448.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/23/2021',
#   'transaction_date': '2021-02-04',
#   'owner': 'self',
#   'ticker': 'DD',
#   'asset_description': 'DuPont De Nemours, Inc',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Alan S. Lowenthal',
#   'district': 'CA47',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018449.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/23/2021',
#   'transaction_date': '2021-02-19',
#   'owner': 'self',
#   'ticker': '--',
#   'asset_description': 'Celegene Corp',
#   'type': 'sale_full',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Alan S. Lowenthal',
#   'district': 'CA47',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018450.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/23/2021',
#   'transaction_date': '2021-02-16',
#   'owner': None,
#   'ticker': '--',
#   'asset_description': 'Outfront Media',
#   'type': 'sale_full',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Hon. Alan S. Lowenthal',
#   'district': 'CA47',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018450.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/23/2021',
#   'transaction_date': '2021-03-15',
#   'owner': 'joint',
#   'ticker': 'COLD',
#   'asset_description': 'Americold Realty Trust Common Shares',
#   'type': 'sale_full',
# ...
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '09/17/2020',
#   'transaction_date': '2020-08-03',
#   'owner': '--',
#   'ticker': 'FB',
#   'asset_description': 'Facebook, Inc. - Class A',
#   'type': 'sale_partial',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. James R. Langevin',
#   'district': 'RI02',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20017387.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '09/17/2020',
#   'transaction_date': '2020-09-08',
#   'owner': 'self',
#   'ticker': 'PSQ',
#   'asset_description': 'ProShares Short QQQ',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Alan S. Lowenthal',
#   'district': 'CA47',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20017389.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '09/17/2020',
#   'transaction_date': '2020-09-08',
#   'owner': 'self',
#   'ticker': 'KTOS',
#   'asset_description': 'Kratos Defense & Security Solutions, Inc.',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Alan S. Lowenthal',
#   'district': 'CA47',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20017390.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '09/17/2020',
#   'transaction_date': '2020-09-09',
#   'owner': 'self',
#   'ticker': 'KTOS',
#   'asset_description': 'Kratos Defense & Security Solutions, Inc.',
#   'type': 'purchase',
#   'amount': '$1,001 -',
#   'representative': 'Hon. Alan S. Lowenthal',
#   'district': 'CA47',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20017390.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '09/17/2020',
#   'transaction_date': '2020-09-10',
#   'owner': 'self',
#   'ticker': 'KTOS',
#   'asset_description': 'Kratos Defense & Security Solutions, Inc.',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Alan S. Lowenthal',
#   'district': 'CA47',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20017390.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '09/17/2020',
#   'transaction_date': '2020-09-08',
#   'owner': 'self',
#   'ticker': 'PSQ',
#   'asset_description': 'ProShares Short QQQ',
#   'type': 'purchase',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Hon. Alan S. Lowenthal',
#   'district': 'CA47',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20017390.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '09/17/2020',
#   'transaction_date': '2020-09-08',
#   'owner': 'self',
#   'ticker': 'KTOS',
#   'asset_description': 'Kratos Defense & Security Solutions, Inc.',
#   'type': 'purchase',
#   'amount': '$1,001 -',
#   'representative': 'Hon. Alan S. Lowenthal',
#   'district': 'CA47',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20017391.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '09/17/2020',
#   'transaction_date': '2020-09-09',
#   'owner': 'self',
#   'ticker': 'KTOS',
#   'asset_description': 'Kratos Defense & Security Solutions, Inc.',
#   'type': 'purchase',
#   'amount': '$1,001 -',
#   'representative': 'Hon. Alan S. Lowenthal',
#   'district': 'CA47',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20017391.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '09/17/2020',
#   'transaction_date': '2020-09-10',
#   'owner': 'self',
#   'ticker': 'KTOS',
#   'asset_description': 'Kratos Defense & Security Solutions, Inc.',
#   'type': 'purchase',
#   'amount': '$1,001 -',
#   'representative': 'Hon. Alan S. Lowenthal',
#   'district': 'CA47',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20017391.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2020,
#   'disclosure_date': '09/17/2020',
#   'transaction_date': '2020-09-08',
#   'owner': 'self',
#   'ticker': 'PSQ',
#   'asset_description': 'ProShares Short QQQ',
#   'type': 'purchase',
#   'amount': '$1,001 -',
#   'representative': 'Hon. Alan S. Lowenthal',
#   'district': 'CA47',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2020/20017391.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-16',
#   'owner': None,
#   'ticker': 'ABT',
#   'asset_description': 'Abbot Laboratories',
#   'type': 'sale_full',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-16',
#   'owner': None,
#   'ticker': 'ABBV',
#   'asset_description': 'AbbVie Inc',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-16',
#   'owner': None,
#   'ticker': 'ACHC',
#   'asset_description': 'Acadia Healthcare Company, Inc',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-16',
#   'owner': None,
#   'ticker': 'ATVI',
#   'asset_description': 'Activision Blizzard Inc',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-17',
#   'owner': None,
#   'ticker': 'ADDDYY',
#   'asset_description': 'Adidas AG Sponsored ADR',
#   'type': 'sale_full',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-16',
#   'owner': None,
#   'ticker': 'ADBE',
#   'asset_description': 'Adobe Inc',
#   'type': 'sale_full',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-16',
#   'owner': None,
#   'ticker': 'AMD',
#   'asset_description': 'Advanced Micro Devices',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-17',
#   'owner': None,
#   'ticker': '--',
#   'asset_description': 'ADYEN N.V. ADR CMN',
#   'type': 'sale_full',
#   'amount': '$50,001 - $100,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-16',
#   'owner': None,
#   'ticker': 'A',
#   'asset_description': 'Agilent Technologies Inc',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-17',
#   'owner': None,
#   'ticker': 'AAGIY',
#   'asset_description': 'AIA Group Ltd',
#   'type': 'sale_full',
#   'amount': '$50,001 - $100,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-16',
#   'owner': None,
#   'ticker': 'AL',
#   'asset_description': 'Air Lease Corporation Class A',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-17',
#   'owner': None,
#   'ticker': 'ALC',
#   'asset_description': 'Alcon Inc',
#   'type': 'sale_full',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-17',
#   'owner': None,
#   'ticker': 'ALFVY',
#   'asset_description': 'Alfa-Laval Ab',
#   'type': 'sale_full',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-17',
#   'owner': None,
#   'ticker': 'BABA',
#   'asset_description': 'Alibab Group Holding Limited',
#   'type': 'sale_full',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': False},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-16',
#   'owner': None,
#   'ticker': 'ADS',
#   'asset_description': 'Alliance Data Systems Corp',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-17',
#   'owner': None,
#   'ticker': '--',
#   'asset_description': 'ALLIANZ SE ADR CMN',
#   'type': 'sale_full',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-16',
#   'owner': None,
#   'ticker': 'GOOGL',
#   'asset_description': 'Alphabet Inc - Class A',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-16',
#   'owner': None,
#   'ticker': 'GOOG',
#   'asset_description': 'Alphabet Inc Class C',
#   'type': 'sale_full',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-16',
#   'owner': None,
#   'ticker': 'AMZN',
#   'asset_description': 'Amazon Inc',
#   'type': 'sale_full',
#   'amount': '$100,001 - $250,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-17',
#   'owner': None,
#   'ticker': 'ABEV',
#   'asset_description': 'Ambev SA America Depository',
#   'type': 'sale_full',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-16',
#   'owner': None,
#   'ticker': 'AMT',
#   'asset_description': 'American Tower Corporation',
#   'type': 'sale_full',
#   'amount': '$15,001 - $50,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-16',
#   'owner': None,
#   'ticker': 'AWK',
#   'asset_description': 'American Water Works Company Inc',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-16',
#   'owner': None,
#   'ticker': 'AMGN',
#   'asset_description': 'Amgen Inc',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-16',
#   'owner': None,
#   'ticker': 'ANTM',
#   'asset_description': 'Anthem Inc',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-16',
#   'owner': None,
#   'ticker': 'AON',
#   'asset_description': 'Aon plc Class A',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-16',
#   'owner': None,
#   'ticker': 'AAPL',
#   'asset_description': 'Apple Inc',
#   'type': 'sale_full',
#   'amount': '$100,001 - $250,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  {'disclosure_year': 2021,
#   'disclosure_date': '03/16/2021',
#   'transaction_date': '2021-02-16',
#   'owner': None,
#   'ticker': 'T',
#   'asset_description': 'AT&T',
#   'type': 'sale_full',
#   'amount': '$1,001 - $15,000',
#   'representative': 'Mr. Peter Meijer',
#   'district': 'MI03',
#   'ptr_link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2021/20018311.pdf',
#   'cap_gains_over_200_usd': True},
#  ...]

# %%
data_stocks = pd.DataFrame(house_stocks.json())
data_stocks.head()
# Out:
#    disclosure_year disclosure_date transaction_date  owner ticker  \
# 0             2021      10/04/2021       2021-09-27  joint     BP
# 1             2021      10/04/2021       2021-09-13  joint    XOM
# 2             2021      10/04/2021       2021-09-10  joint   ILPT
# 3             2021      10/04/2021       2021-09-28  joint     PM
# 4             2021      10/04/2021       2021-09-17   self    BLK
#
#                                    asset_description          type  \
# 0                                             BP plc      purchase
# 1                            Exxon Mobil Corporation      purchase
# 2  Industrial Logistics Properties Trust - Common...      purchase
# 3                   Phillip Morris International Inc      purchase
# 4                                      BlackRock Inc  sale_partial
#
#               amount          representative district  \
# 0   $1,001 - $15,000      Hon. Virginia Foxx     NC05
# 1   $1,001 - $15,000      Hon. Virginia Foxx     NC05
# 2  $15,001 - $50,000      Hon. Virginia Foxx     NC05
# 3  $15,001 - $50,000      Hon. Virginia Foxx     NC05
# 4   $1,001 - $15,000  Hon. Alan S. Lowenthal     CA47
#
#                                             ptr_link  cap_gains_over_200_usd
# 0  https://disclosures-clerk.house.gov/public_dis...                   False
# 1  https://disclosures-clerk.house.gov/public_dis...                   False
# 2  https://disclosures-clerk.house.gov/public_dis...                   False
# 3  https://disclosures-clerk.house.gov/public_dis...                   False
# 4  https://disclosures-clerk.house.gov/public_dis...                   False
